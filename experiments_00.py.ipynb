# %%
import requests
from bs4 import BeautifulSoup

# %%
r=requests.get("https://www.instagram.com/p/B9Z68xjhFbY/")
c=r.content #this is the content in HTML, optionally I can print(c)
soup=BeautifulSoup(c,"html.parser") #optionally I can print(soup)
#print(soup.find_all("script")[3].string.find_parent("div"))
script=(soup.find_all("script"))
print(script[4]) #aquí se encuentra la URL del video.
#print(script[4].find_all("BaseURL"))#,{"class":"propPrice"}) #.text.replace("\n","").replace(" ","")
# Out:
# <script type="text/javascript">window._sharedData = {"config":{"csrf_token":"66F3HGATFspYU9r4di7WORAnZKI1MMVg","viewer":null,"viewerId":null},"country_code":"MX","language_code":"en","locale":"en_US","entry_data":{"PostPage":[{"graphql":{"shortcode_media":{"__typename":"GraphVideo","id":"2259095951178487512","shortcode":"B9Z68xjhFbY","dimensions":{"height":480,"width":480},"gating_info":null,"fact_check_overall_rating":null,"fact_check_information":null,"media_preview":"","display_url":"https://instagram.fgdl4-1.fna.fbcdn.net/v/t51.2885-15/e35/83629712_524261668230252_6096750457115862195_n.jpg?_nc_ht=instagram.fgdl4-1.fna.fbcd
# ...

# %%
https://instagram.fgdl4-1.fna.fbcdn.net/v/t50.2886-16/87210875_126663472249126_4534613468675188266_n.mp4?_nc_ht=instagram.fgdl4-1.fna.fbcdn.net\u0026_nc_cat=110\u0026_nc_ohc=MU8yDiVaBAwAX_82OpZ\u0026oe=5E65A934\u0026oh=042d47a1484a01f36cdbed38e8d60e04
https://instagram.fgdl4-1.fna.fbcdn.net/v/t50.2886-16/87210875_126663472249126_4534613468675188266_n.mp4?_nc_ht=instagram.fgdl4-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=MU8yDiVaBAwAX_82OpZ&oe=5E65A934&oh=042d47a1484a01f36cdbed38e8d60e04
